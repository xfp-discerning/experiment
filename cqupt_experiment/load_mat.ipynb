# %%
import scipy.io as scio
import pandas as pd

# %%
data_path='./cqupt_data/AP7database20141105.mat'
data=scio.loadmat(data_path)
#查看导入后的data为dict类型
type(data)
# Out:
# dict

# %%
data.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'AXY1', 'AXY2', 'AXY3', 'AXY4', 'AXY5', 'A4', 'A5', 'A3', 'A1', 'A2'])

# %%
type(data['A1'])
# Out:
# numpy.ndarray

# %%
data['AXY1'].shape
# Out:
# (58, 2)

# %%
data['AXY1'][0]`
# Out:
# array([34.9 ,  8.23])

# %%
data
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN, Created on: Thu Nov 06 16:20:59 2014',
#  '__version__': '1.0',
#  '__globals__': [],
#  'AXY1': array([[34.9 ,  8.23],
#         [34.2 ,  8.43],
#         [33.6 ,  8.43],
#         [33.  ,  8.43],
#         [32.4 ,  8.43],
#         [31.8 ,  8.43],
#         [31.2 ,  8.43],
#         [30.6 ,  8.43],
#         [30.  ,  8.43],
#         [29.4 ,  8.43],
#         [28.8 ,  8.43],
#         [28.2 ,  8.43],
#         [27.6 ,  8.43],
#         [27.  ,  8.43],
#         [26.4 ,  8.43],
#         [25.8 ,  8.43],
#         [25.2 ,  8.43],
#         [24.6 ,  8.43],
#         [24.  ,  8.43],
#         [23.4 ,  8.43],
#         [22.8 ,  8.43],
#         [22.2 ,  8.43],
#         [21.6 ,  8.43],
#         [21.  ,  8.43],
#         [20.4 ,  8.43],
#         [19.8 ,  8.43],
#         [19.2 ,  8.43],
#         [18.6 ,  8.43],
#         [18.  ,  8.43],
#         [17.4 ,  8.43],
#         [16.8 ,  8.43],
#         [16.2 ,  8.43],
# ...
