# %%
import tensorflow as tf
import pandas as pd
import numpy as np
from sklearn.preprocessing import scale

# %%
path = "./UJIIndoorLoc/children_13/sorted/00_sorted.csv"
train_df = pd.read_csv(path,header=0)
print(train_df.shape)
a = train_df.mean()
a["WAP004"]
for i in train_df.columns[:520]:
    if a[i]==-110:
        del train_df[i]
train_df.shape
# Out:
# (1059, 531)
# (1059, 130)

# %%
train_df
# Out:
#       WAP007  WAP008  WAP009  WAP013  WAP014  WAP017  WAP018  WAP019  WAP020  \
# 0       -110    -110    -110    -110    -110    -110    -110    -110    -110
# 1       -110    -110    -110    -110    -110    -110    -110    -110    -110
# 2       -110    -110    -110    -110    -110    -110    -110    -110    -110
# 3       -110    -110    -110    -110    -110    -110    -110     -80     -80
# 4       -110    -110    -110    -110    -110    -110    -110    -110    -110
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 1054     -84    -110    -110    -110    -110    -110    -110    -110    -110
# 1055    -110    -110    -110    -110    -110    -110    -110    -110    -110
# 1056    -110    -110    -110    -110    -110    -110    -110    -110    -110
# 1057    -110    -110    -110    -110    -110    -110    -110    -110    -110
# 1058    -110    -110    -110    -110    -110    -110    -110    -110    -110
#
#       WAP023  ...     LATITUDE  BUILDINGID  FLOOR  SPACEID  RELATIVEPOSITION  \
# 0       -110  ...  4864949.814           0      0      102                 2
# 1       -110  ...  4864949.814           0      0      102                 2
# 2       -110  ...  4864949.814           0      0      102                 2
# 3       -110  ...  4864949.814           0      0      102                 2
# 4       -110  ...  4864949.814           0      0      102                 2
# ...      ...  ...          ...         ...    ...      ...               ...
# 1054    -110  ...  4864931.492           0      0      237                 2
# 1055    -110  ...  4864931.492           0      0      237                 2
# 1056    -110  ...  4864931.492           0      0      237                 2
# 1057    -110  ...  4864931.492           0      0      237                 2
# 1058    -110  ...  4864931.492           0      0      237                 2
#
#       USERID  PHONEID   TIMESTAMP  BF   REF
# 0          1       14  1371047344   0  1022
# 1         11       13  1369908924   0  1022
# 2          1       14  1371047344   0  1022
# 3         11       13  1369908951   0  1022
# 4          1       14  1371047343   0  1022
# ...      ...      ...         ...  ..   ...
# 1054      11       13  1369911205   0  2372
# 1055       1       14  1370878737   0  2372
# 1056       1       14  1370878736   0  2372
# 1057       1       14  1370878737   0  2372
# 1058       1       14  1370878736   0  2372
#
# [1059 rows x 130 columns]
